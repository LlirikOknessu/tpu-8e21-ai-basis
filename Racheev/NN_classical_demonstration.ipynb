# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense
print("TensorFlow version:", tf.__version__)
# Load the TensorBoard notebook extension
# %load_ext tensorboard
import datetime
import shutil
# Out:
# TensorFlow version: 2.18.0

# %%
 # %reload_ext tensorboard
from tensorflow.keras import Model
from pathlib import Path
import pandas as pd

# %%
BATCH_SIZE = 64
BUFFER_SIZE = 128
LEARNING_RATE = 0.05
EPOCHS = 50

# %%
input_dir = Path('./data/prepared')
logs_path = Path('./data/logs')
#if logs_path.exists():
#  shutil.rmtree(logs_path)
logs_path.mkdir(exist_ok=True,parents=True)

X_train_name = input_dir / 'X_train.csv'
y_train_name = input_dir / 'y_train.csv'
X_test_name = input_dir / 'X_test.csv'
y_test_name = input_dir / 'y_test.csv'

X_train = pd.read_csv(X_train_name)
y_train = pd.read_csv(y_train_name)
X_test = pd.read_csv(X_test_name)
y_test = pd.read_csv(y_test_name)

train_ds = tf.data.Dataset.from_tensor_slices(
    (X_train, y_train)).shuffle(BUFFER_SIZE).batch(BATCH_SIZE)

test_ds = tf.data.Dataset.from_tensor_slices((X_test, y_test)).batch(BATCH_SIZE)

# %%
from tensorflow.keras.layers import Dense, Input

def create_model():
    model = tf.keras.models.Sequential([
        Input(shape=(8,)),  
        Dense(128, activation='relu'), 
        Dense(64, activation='relu'), 
        Dense(1, activation='linear')
    ])
    return model

# %%
model = create_model()

model.compile(
    optimizer='adam',
    loss='mse',
    metrics=['mae']
)

# %%
logdir = logs_path / 'new_log'
logdir.mkdir(exist_ok=True, parents=True)
tensorboard_callback = tf.keras.callbacks.TensorBoard(
    log_dir=str(logdir),
    histogram_freq=1,  # Записывать гистограммы весов каждые 1 эпоху
    write_graph=True,  # Включить сохранение графа
    write_images=True  # Сохранение весов как изображений
)

# %%
model.fit(
    train_ds,
    validation_data=test_ds,
    epochs=100,
    callbacks=[tensorboard_callback]
)
# Out:
# Epoch 1/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1162.4861 - mae: 24.5166 - val_loss: 19.1773 - val_mae: 3.4156
# Epoch 2/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 17.4894 - mae: 2.8305 - val_loss: 10.6401 - val_mae: 2.2899
# Epoch 3/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 11.9519 - mae: 2.3828 - val_loss: 6.6620 - val_mae: 1.7969
# Epoch 4/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.8487 - mae: 1.7649 - val_loss: 3.5778 - val_mae: 1.2309
# Epoch 5/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9040 - mae: 1.3256 - val_loss: 2.2827 - val_mae: 1.0037
# Epoch 6/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4302 - mae: 1.0622 - val_loss: 1.5322 - val_mae: 0.8621
# Epoch 7/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6136 - mae: 0.8951 - val_loss: 1.3153 - val_mae: 0.8968
# Epoch 8/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0434 - mae: 0.7218 - val_loss: 0.8180 - val_mae: 0.7299
# Epoch 9/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7187 - mae: 0.6103 - val_loss: 0.6180 - val_mae: 0.6667
# Epoch 10/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4717 - mae: 0.5220 - val_loss: 0.2504 - val_mae: 0.3959
# Epoch 11/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2564 - mae: 0.3826 - val_loss: 0.2292 - val_mae: 0.4039
# Epoch 12/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1937 - mae: 0.3284 - val_loss: 0.1249 - val_mae: 0.2823
# Epoch 13/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1107 - mae: 0.2542 - val_loss: 0.0854 - val_mae: 0.2258
# Epoch 14/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0853 - mae: 0.2226 - val_loss: 0.0635 - val_mae: 0.1909
# Epoch 15/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0641 - mae: 0.1947 - val_loss: 0.0680 - val_mae: 0.2107
# Epoch 16/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0643 - mae: 0.1969 - val_loss: 0.0429 - val_mae: 0.1571
# Epoch 17/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0469 - mae: 0.1685 - val_loss: 0.0477 - val_mae: 0.1632
# Epoch 18/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0365 - mae: 0.1495 - val_loss: 0.0330 - val_mae: 0.1386
# Epoch 19/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0308 - mae: 0.1375 - val_loss: 0.0333 - val_mae: 0.1380
# Epoch 20/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0282 - mae: 0.1298 - val_loss: 0.0256 - val_mae: 0.1227
# Epoch 21/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0251 - mae: 0.1238 - val_loss: 0.0231 - val_mae: 0.1164
# Epoch 22/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0223 - mae: 0.1156 - val_loss: 0.0217 - val_mae: 0.1134
# Epoch 23/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0230 - mae: 0.1161 - val_loss: 0.0208 - val_mae: 0.1112
# Epoch 24/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0229 - mae: 0.1157 - val_loss: 0.0263 - val_mae: 0.1273
# Epoch 25/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0209 - mae: 0.1103 - val_loss: 0.0227 - val_mae: 0.1100
# Epoch 26/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0165 - mae: 0.0977 - val_loss: 0.0158 - val_mae: 0.0951
# Epoch 27/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0169 - mae: 0.0982 - val_loss: 0.0301 - val_mae: 0.1409
# Epoch 28/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0173 - mae: 0.0993 - val_loss: 0.0339 - val_mae: 0.1521
# Epoch 29/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0224 - mae: 0.1147 - val_loss: 0.0159 - val_mae: 0.0973
# Epoch 30/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0138 - mae: 0.0879 - val_loss: 0.0225 - val_mae: 0.1088
# Epoch 31/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0141 - mae: 0.0881 - val_loss: 0.0244 - val_mae: 0.1278
# Epoch 32/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0156 - mae: 0.0937 - val_loss: 0.0114 - val_mae: 0.0764
# Epoch 33/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0136 - mae: 0.0863 - val_loss: 0.0107 - val_mae: 0.0761
# Epoch 34/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0144 - mae: 0.0898 - val_loss: 0.0446 - val_mae: 0.1840
# Epoch 35/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0193 - mae: 0.1040 - val_loss: 0.0106 - val_mae: 0.0779
# Epoch 36/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0094 - mae: 0.0720 - val_loss: 0.0300 - val_mae: 0.1474
# Epoch 37/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0148 - mae: 0.0919 - val_loss: 0.0114 - val_mae: 0.0739
# Epoch 38/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0128 - mae: 0.0851 - val_loss: 0.0127 - val_mae: 0.0896
# Epoch 39/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0154 - mae: 0.0927 - val_loss: 0.0111 - val_mae: 0.0819
# Epoch 40/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0103 - mae: 0.0767 - val_loss: 0.0388 - val_mae: 0.1627
# Epoch 41/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0265 - mae: 0.1274 - val_loss: 0.0095 - val_mae: 0.0737
# Epoch 42/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0116 - mae: 0.0806 - val_loss: 0.0123 - val_mae: 0.0769
# Epoch 43/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0126 - mae: 0.0842 - val_loss: 0.0219 - val_mae: 0.1108
# Epoch 44/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0115 - mae: 0.0786 - val_loss: 0.0202 - val_mae: 0.1048
# Epoch 45/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0143 - mae: 0.0892 - val_loss: 0.0225 - val_mae: 0.1132
# Epoch 46/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0162 - mae: 0.0964 - val_loss: 0.0095 - val_mae: 0.0750
# Epoch 47/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0115 - mae: 0.0795 - val_loss: 0.1573 - val_mae: 0.3651
# Epoch 48/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0768 - mae: 0.2232 - val_loss: 0.0195 - val_mae: 0.1183
# Epoch 49/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0166 - mae: 0.1006 - val_loss: 0.0496 - val_mae: 0.1992
# Epoch 50/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0354 - mae: 0.1493 - val_loss: 0.0237 - val_mae: 0.1317
# Epoch 51/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0364 - mae: 0.1521 - val_loss: 0.0373 - val_mae: 0.1604
# Epoch 52/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0179 - mae: 0.1019 - val_loss: 0.0469 - val_mae: 0.1934
# Epoch 53/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0353 - mae: 0.1466 - val_loss: 0.0094 - val_mae: 0.0662
# Epoch 54/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0142 - mae: 0.0870 - val_loss: 0.0168 - val_mae: 0.0936
# Epoch 55/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0241 - mae: 0.1177 - val_loss: 0.0614 - val_mae: 0.2187
# Epoch 56/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0905 - mae: 0.2326 - val_loss: 0.1580 - val_mae: 0.3660
# Epoch 57/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0359 - mae: 0.1394 - val_loss: 0.0153 - val_mae: 0.0866
# Epoch 58/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0222 - mae: 0.1031 - val_loss: 0.0087 - val_mae: 0.0718
# Epoch 59/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1096 - mae: 0.2639 - val_loss: 0.0143 - val_mae: 0.0869
# Epoch 60/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0769 - mae: 0.1902 - val_loss: 0.0098 - val_mae: 0.0683
# Epoch 61/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.0021 - mae: 0.9509 - val_loss: 9.9288 - val_mae: 2.9560
# Epoch 62/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0323 - mae: 1.1280 - val_loss: 0.0532 - val_mae: 0.2068
# Epoch 63/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0323 - mae: 0.1412 - val_loss: 0.0083 - val_mae: 0.0672
# Epoch 64/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0138 - mae: 0.0871 - val_loss: 0.0274 - val_mae: 0.1332
# Epoch 65/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0463 - mae: 0.1689 - val_loss: 0.0731 - val_mae: 0.2465
# Epoch 66/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1588 - mae: 0.3160 - val_loss: 0.0235 - val_mae: 0.1321
# Epoch 67/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0317 - mae: 0.1428 - val_loss: 0.2026 - val_mae: 0.4210
# Epoch 68/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0743 - mae: 0.2158 - val_loss: 0.0100 - val_mae: 0.0795
# Epoch 69/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0295 - mae: 0.1344 - val_loss: 0.1132 - val_mae: 0.3113
# Epoch 70/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1540 - mae: 0.3205 - val_loss: 0.0094 - val_mae: 0.0753
# Epoch 71/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0745 - mae: 0.1828 - val_loss: 0.7701 - val_mae: 0.8295
# Epoch 72/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.6481 - mae: 2.3349 - val_loss: 7.2747 - val_mae: 2.5836
# Epoch 73/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5720 - mae: 1.2301 - val_loss: 0.4286 - val_mae: 0.5937
# Epoch 74/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5794 - mae: 0.5711 - val_loss: 0.0177 - val_mae: 0.1155
# Epoch 75/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0159 - mae: 0.0981 - val_loss: 0.0230 - val_mae: 0.1312
# Epoch 76/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0323 - mae: 0.1411 - val_loss: 0.0078 - val_mae: 0.0647
# Epoch 77/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0122 - mae: 0.0841 - val_loss: 0.0593 - val_mae: 0.2200
# Epoch 78/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0598 - mae: 0.1997 - val_loss: 0.0080 - val_mae: 0.0628
# Epoch 79/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0519 - mae: 0.1687 - val_loss: 0.0166 - val_mae: 0.1080
# Epoch 80/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1854 - mae: 0.2604 - val_loss: 0.7866 - val_mae: 0.8395
# Epoch 81/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2009 - mae: 0.3364 - val_loss: 0.0150 - val_mae: 0.1031
# Epoch 82/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1969 - mae: 0.3250 - val_loss: 0.8601 - val_mae: 0.8790
# Epoch 83/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.6297 - mae: 1.6371 - val_loss: 185.2289 - val_mae: 12.9589
# Epoch 84/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 74.6271 - mae: 6.6771 - val_loss: 0.1283 - val_mae: 0.2294
# Epoch 85/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2775 - mae: 0.3781 - val_loss: 0.0138 - val_mae: 0.0860
# Epoch 86/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0167 - mae: 0.0950 - val_loss: 0.0094 - val_mae: 0.0654
# Epoch 87/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0085 - mae: 0.0662 - val_loss: 0.0170 - val_mae: 0.0902
# Epoch 88/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0140 - mae: 0.0892 - val_loss: 0.0140 - val_mae: 0.0966
# Epoch 89/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0089 - mae: 0.0688 - val_loss: 0.0105 - val_mae: 0.0692
# Epoch 90/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0093 - mae: 0.0710 - val_loss: 0.0374 - val_mae: 0.1616
# Epoch 91/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0143 - mae: 0.0897 - val_loss: 0.0580 - val_mae: 0.2162
# Epoch 92/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0190 - mae: 0.1043 - val_loss: 0.0162 - val_mae: 0.1055
# Epoch 93/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0092 - mae: 0.0706 - val_loss: 0.0153 - val_mae: 0.1021
# Epoch 94/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0164 - mae: 0.0980 - val_loss: 0.0083 - val_mae: 0.0680
# Epoch 95/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0085 - mae: 0.0676 - val_loss: 0.0080 - val_mae: 0.0654
# Epoch 96/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0148 - mae: 0.0899 - val_loss: 0.0093 - val_mae: 0.0752
# Epoch 97/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0118 - mae: 0.0825 - val_loss: 0.0158 - val_mae: 0.0901
# Epoch 98/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0144 - mae: 0.0920 - val_loss: 0.0086 - val_mae: 0.0701
# Epoch 99/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0119 - mae: 0.0828 - val_loss: 0.0092 - val_mae: 0.0658
# Epoch 100/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0089 - mae: 0.0693 - val_loss: 0.0225 - val_mae: 0.1153

# %%
# %tensorboard --logdir ./data/logs --port=8888
# Out:
# ERROR: Failed to launch TensorBoard (exited with 4294967295).
# Contents of stderr:
# 2025-01-18 01:28:45.804474: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-01-18 01:28:46.326737: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# E0118 01:28:48.585180 26084 program.py:300] TensorBoard could not bind to port 8888, it was already in use
# ERROR: TensorBoard could not bind to port 8888, it was already in use

# %%
# !kill 23644
# Out:
# "kill" ­Ґ пў«пҐвбп ў­гваҐ­­Ґ© Ё«Ё ў­Ґи­Ґ©
# Є®¬ ­¤®©, ЁбЇ®«­пҐ¬®© Їа®Ја ¬¬®© Ё«Ё Ї ЄҐв­л¬ д ©«®¬.
