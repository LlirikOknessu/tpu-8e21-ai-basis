# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense
print("TensorFlow version:", tf.__version__)
# Load the TensorBoard notebook extension
# %load_ext tensorboard
import datetime
import shutil
# Out:
# TensorFlow version: 2.18.0

# %%
 # %reload_ext tensorboard
from tensorflow.keras import Model
from pathlib import Path
import pandas as pd

# %%
BATCH_SIZE = 64
BUFFER_SIZE = 128
LEARNING_RATE = 0.05
EPOCHS = 50

# %%
input_dir = Path('./data/prepared')
logs_path = Path('./data/logs')
#if logs_path.exists():
#  shutil.rmtree(logs_path)
logs_path.mkdir(exist_ok=True,parents=True)

X_train_name = input_dir / 'X_train.csv'
y_train_name = input_dir / 'y_train.csv'
X_test_name = input_dir / 'X_test.csv'
y_test_name = input_dir / 'y_test.csv'

X_train = pd.read_csv(X_train_name)
y_train = pd.read_csv(y_train_name)
X_test = pd.read_csv(X_test_name)
y_test = pd.read_csv(y_test_name)

train_ds = tf.data.Dataset.from_tensor_slices(
    (X_train, y_train)).shuffle(BUFFER_SIZE).batch(BATCH_SIZE)

test_ds = tf.data.Dataset.from_tensor_slices((X_test, y_test)).batch(BATCH_SIZE)

# %%
from tensorflow.keras.layers import Dense, Input

def create_model():
    model = tf.keras.models.Sequential([
        Input(shape=(8,)),  
        Dense(128, activation='relu'), 
        Dense(64, activation='relu'), 
        Dense(1, activation='linear')
    ])
    return model

# %%
model = create_model()

model.compile(
    optimizer='adam',
    loss='mse',
    metrics=['mae']
)

# %%
logdir = logs_path / 'new_log'
logdir.mkdir(exist_ok=True, parents=True)
tensorboard_callback = tf.keras.callbacks.TensorBoard(
    log_dir=str(logdir),
    histogram_freq=1,  # Записывать гистограммы весов каждые 1 эпоху
    write_graph=True,  # Включить сохранение графа
    write_images=True  # Сохранение весов как изображений
)

# %%
model.fit(
    train_ds,
    validation_data=test_ds,
    epochs=100,
    callbacks=[tensorboard_callback]
)
# Out:
# Epoch 1/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 2.6474 - mae: 1.1256 - val_loss: 0.0594 - val_mae: 0.2028
# Epoch 2/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0366 - mae: 0.1497 - val_loss: 0.0189 - val_mae: 0.1091
# Epoch 3/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0159 - mae: 0.0992 - val_loss: 0.0186 - val_mae: 0.1064
# Epoch 4/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0177 - mae: 0.1042 - val_loss: 0.0123 - val_mae: 0.0866
# Epoch 5/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0109 - mae: 0.0813 - val_loss: 0.0100 - val_mae: 0.0757
# Epoch 6/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0109 - mae: 0.0802 - val_loss: 0.0167 - val_mae: 0.1007
# Epoch 7/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0107 - mae: 0.0774 - val_loss: 0.0074 - val_mae: 0.0650
# Epoch 8/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0084 - mae: 0.0699 - val_loss: 0.0080 - val_mae: 0.0674
# Epoch 9/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0078 - mae: 0.0673 - val_loss: 0.0111 - val_mae: 0.0802
# Epoch 10/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0074 - mae: 0.0660 - val_loss: 0.0195 - val_mae: 0.1150
# Epoch 11/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0084 - mae: 0.0693 - val_loss: 0.0114 - val_mae: 0.0856
# Epoch 12/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0068 - mae: 0.0621 - val_loss: 0.0085 - val_mae: 0.0736
# Epoch 13/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0070 - mae: 0.0638 - val_loss: 0.0122 - val_mae: 0.0880
# Epoch 14/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0066 - mae: 0.0610 - val_loss: 0.0088 - val_mae: 0.0723
# Epoch 15/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0070 - mae: 0.0639 - val_loss: 0.0318 - val_mae: 0.1551
# Epoch 16/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0124 - mae: 0.0850 - val_loss: 0.0056 - val_mae: 0.0569
# Epoch 17/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0058 - mae: 0.0577 - val_loss: 0.0068 - val_mae: 0.0618
# Epoch 18/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0057 - mae: 0.0574 - val_loss: 0.0150 - val_mae: 0.0963
# Epoch 19/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0089 - mae: 0.0737 - val_loss: 0.0226 - val_mae: 0.1318
# Epoch 20/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0088 - mae: 0.0720 - val_loss: 0.0067 - val_mae: 0.0624
# Epoch 21/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0062 - mae: 0.0589 - val_loss: 0.0086 - val_mae: 0.0691
# Epoch 22/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0093 - mae: 0.0725 - val_loss: 0.0169 - val_mae: 0.1096
# Epoch 23/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0159 - mae: 0.1011 - val_loss: 0.0090 - val_mae: 0.0702
# Epoch 24/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0075 - mae: 0.0648 - val_loss: 0.0700 - val_mae: 0.2466
# Epoch 25/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0259 - mae: 0.1231 - val_loss: 0.0405 - val_mae: 0.1837
# Epoch 26/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0362 - mae: 0.1582 - val_loss: 0.0068 - val_mae: 0.0624
# Epoch 27/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0164 - mae: 0.0990 - val_loss: 0.0250 - val_mae: 0.1327
# Epoch 28/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0098 - mae: 0.0760 - val_loss: 0.1120 - val_mae: 0.3082
# Epoch 29/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0426 - mae: 0.1611 - val_loss: 0.0070 - val_mae: 0.0643
# Epoch 30/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0241 - mae: 0.1175 - val_loss: 0.0070 - val_mae: 0.0634
# Epoch 31/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0148 - mae: 0.0964 - val_loss: 0.0098 - val_mae: 0.0751
# Epoch 32/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0088 - mae: 0.0723 - val_loss: 0.1224 - val_mae: 0.3206
# Epoch 33/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0555 - mae: 0.1903 - val_loss: 0.0089 - val_mae: 0.0792
# Epoch 34/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0160 - mae: 0.0992 - val_loss: 0.0119 - val_mae: 0.0878
# Epoch 35/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0125 - mae: 0.0883 - val_loss: 0.0073 - val_mae: 0.0663
# Epoch 36/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0069 - mae: 0.0631 - val_loss: 0.0049 - val_mae: 0.0518
# Epoch 37/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0118 - mae: 0.0823 - val_loss: 0.0064 - val_mae: 0.0625
# Epoch 38/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0471 - mae: 0.1721 - val_loss: 0.0252 - val_mae: 0.1317
# Epoch 39/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0098 - mae: 0.0759 - val_loss: 0.0085 - val_mae: 0.0718
# Epoch 40/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0097 - mae: 0.0768 - val_loss: 0.0103 - val_mae: 0.0780
# Epoch 41/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0109 - mae: 0.0804 - val_loss: 0.0299 - val_mae: 0.1515
# Epoch 42/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0121 - mae: 0.0872 - val_loss: 0.0047 - val_mae: 0.0507
# Epoch 43/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0058 - mae: 0.0568 - val_loss: 0.0059 - val_mae: 0.0560
# Epoch 44/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0079 - mae: 0.0677 - val_loss: 0.0639 - val_mae: 0.2269
# Epoch 45/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0168 - mae: 0.0991 - val_loss: 0.0201 - val_mae: 0.1235
# Epoch 46/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0183 - mae: 0.1022 - val_loss: 0.0049 - val_mae: 0.0525
# Epoch 47/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0078 - mae: 0.0662 - val_loss: 0.0203 - val_mae: 0.1250
# Epoch 48/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0169 - mae: 0.0977 - val_loss: 0.0061 - val_mae: 0.0605
# Epoch 49/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0163 - mae: 0.1000 - val_loss: 0.0874 - val_mae: 0.2776
# Epoch 50/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0251 - mae: 0.1228 - val_loss: 0.0053 - val_mae: 0.0541
# Epoch 51/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0060 - mae: 0.0575 - val_loss: 0.0053 - val_mae: 0.0541
# Epoch 52/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0397 - mae: 0.1593 - val_loss: 0.0214 - val_mae: 0.1164
# Epoch 53/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0287 - mae: 0.1326 - val_loss: 0.0192 - val_mae: 0.1143
# Epoch 54/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0113 - mae: 0.0806 - val_loss: 0.0079 - val_mae: 0.0661
# Epoch 55/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0079 - mae: 0.0678 - val_loss: 0.0559 - val_mae: 0.2220
# Epoch 56/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0276 - mae: 0.1334 - val_loss: 0.0089 - val_mae: 0.0726
# Epoch 57/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0126 - mae: 0.0881 - val_loss: 0.0075 - val_mae: 0.0638
# Epoch 58/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0197 - mae: 0.1133 - val_loss: 0.0133 - val_mae: 0.0937
# Epoch 59/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0096 - mae: 0.0731 - val_loss: 0.0159 - val_mae: 0.0988
# Epoch 60/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0115 - mae: 0.0826 - val_loss: 0.0424 - val_mae: 0.1887
# Epoch 61/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0235 - mae: 0.1254 - val_loss: 0.4036 - val_mae: 0.5995
# Epoch 62/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1424 - mae: 0.3122 - val_loss: 0.0067 - val_mae: 0.0662
# Epoch 63/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0099 - mae: 0.0760 - val_loss: 0.0075 - val_mae: 0.0650
# Epoch 64/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0087 - mae: 0.0708 - val_loss: 0.0212 - val_mae: 0.1264
# Epoch 65/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0128 - mae: 0.0883 - val_loss: 0.0047 - val_mae: 0.0494
# Epoch 66/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0138 - mae: 0.0921 - val_loss: 0.0052 - val_mae: 0.0542
# Epoch 67/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0089 - mae: 0.0739 - val_loss: 0.0065 - val_mae: 0.0571
# Epoch 68/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0126 - mae: 0.0866 - val_loss: 0.0048 - val_mae: 0.0506
# Epoch 69/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0109 - mae: 0.0789 - val_loss: 0.0213 - val_mae: 0.1252
# Epoch 70/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0146 - mae: 0.0973 - val_loss: 0.2302 - val_mae: 0.4572
# Epoch 71/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0884 - mae: 0.2462 - val_loss: 0.0142 - val_mae: 0.0927
# Epoch 72/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0111 - mae: 0.0808 - val_loss: 0.0058 - val_mae: 0.0557
# Epoch 73/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0059 - mae: 0.0562 - val_loss: 0.0141 - val_mae: 0.1003
# Epoch 74/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0073 - mae: 0.0636 - val_loss: 0.0059 - val_mae: 0.0576
# Epoch 75/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0072 - mae: 0.0640 - val_loss: 0.0052 - val_mae: 0.0545
# Epoch 76/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0085 - mae: 0.0691 - val_loss: 0.0147 - val_mae: 0.1013
# Epoch 77/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0246 - mae: 0.1227 - val_loss: 0.0552 - val_mae: 0.2104
# Epoch 78/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0295 - mae: 0.1353 - val_loss: 0.0068 - val_mae: 0.0636
# Epoch 79/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0082 - mae: 0.0694 - val_loss: 0.0045 - val_mae: 0.0486
# Epoch 80/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0075 - mae: 0.0643 - val_loss: 0.0149 - val_mae: 0.0979
# Epoch 81/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0157 - mae: 0.0996 - val_loss: 0.0139 - val_mae: 0.0972
# Epoch 82/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0089 - mae: 0.0712 - val_loss: 0.0414 - val_mae: 0.1873
# Epoch 83/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0208 - mae: 0.1138 - val_loss: 0.0044 - val_mae: 0.0481
# Epoch 84/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0070 - mae: 0.0612 - val_loss: 0.0044 - val_mae: 0.0483
# Epoch 85/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0164 - mae: 0.0982 - val_loss: 0.0158 - val_mae: 0.1002
# Epoch 86/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0082 - mae: 0.0685 - val_loss: 0.0077 - val_mae: 0.0670
# Epoch 87/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0062 - mae: 0.0592 - val_loss: 0.0092 - val_mae: 0.0751
# Epoch 88/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0095 - mae: 0.0756 - val_loss: 0.0059 - val_mae: 0.0561
# Epoch 89/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0061 - mae: 0.0581 - val_loss: 0.0650 - val_mae: 0.2369
# Epoch 90/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0560 - mae: 0.1922 - val_loss: 0.0055 - val_mae: 0.0553
# Epoch 91/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0143 - mae: 0.0931 - val_loss: 0.0427 - val_mae: 0.1931
# Epoch 92/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0208 - mae: 0.1154 - val_loss: 0.0558 - val_mae: 0.2138
# Epoch 93/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0282 - mae: 0.1383 - val_loss: 0.0063 - val_mae: 0.0565
# Epoch 94/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0076 - mae: 0.0678 - val_loss: 0.0050 - val_mae: 0.0516
# Epoch 95/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0074 - mae: 0.0630 - val_loss: 0.0575 - val_mae: 0.2116
# Epoch 96/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0325 - mae: 0.1377 - val_loss: 0.0054 - val_mae: 0.0524
# Epoch 97/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0070 - mae: 0.0628 - val_loss: 0.0089 - val_mae: 0.0767
# Epoch 98/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0169 - mae: 0.1045 - val_loss: 0.0377 - val_mae: 0.1672
# Epoch 99/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0222 - mae: 0.1093 - val_loss: 0.0053 - val_mae: 0.0553
# Epoch 100/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0067 - mae: 0.0617 - val_loss: 0.0068 - val_mae: 0.0629

# %%
# %tensorboard --logdir ./data/logs --port=8088
# Out:
# Reusing TensorBoard on port 8088 (pid 31200), started 2 days, 15:23:50 ago. (Use '!kill 31200' to kill it.)
#       <iframe id="tensorboard-frame-92fd7bf8b4317cbe" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-92fd7bf8b4317cbe");
#           const url = new URL("/", window.location);
#           const port = 8088;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# !kill 23644
# Out:
# "kill" ­Ґ пў«пҐвбп ў­гваҐ­­Ґ© Ё«Ё ў­Ґи­Ґ©
# Є®¬ ­¤®©, ЁбЇ®«­пҐ¬®© Їа®Ја ¬¬®© Ё«Ё Ї ЄҐв­л¬ д ©«®¬.
